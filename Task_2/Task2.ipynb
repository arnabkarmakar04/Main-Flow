# %% [markdown]
# Importing pandas and creating a dataframe

# %%
import pandas as pd

df = pd.read_csv("Task_2.csv")
df.head()
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# 1        351.050         329.067  1.549       537.201  ...        60.012
# 2        350.022         329.260  1.600       549.611  ...        61.304
# 3        350.938         331.142  1.604       623.362  ...        68.496
# 4        351.640         332.709    NaN       638.672  ...        70.022
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
df.count()
# Out:
# Observation        324
# Y-Kappa            324
# ChipRate           319
# BF-CMratio         307
# BlowFlow           308
# ChipLevel4         323
# T-upperExt-2       322
# T-lowerExt-2       322
# UCZAA              299
# WhiteFlow-4        323
# AAWhiteSt-4        173
# AA-Wood-4          323
# ChipMoisture-4     323
# SteamFlow-4        323
# Lower-HeatT-3      322
# Upper-HeatT-3      322
# ChipMass-4         323
# WeakLiquorF        323
# BlackFlow-2        322
# WeakWashF          323
# SteamHeatF-3       322
# T-Top-Chips-4      323
# SulphidityL-4      173
# dtype: int64

# %% [markdown]
# Dropping the duplicate rows (if any)

# %%
df.drop_duplicates()
df.head()
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# 1        351.050         329.067  1.549       537.201  ...        60.012
# 2        350.022         329.260  1.600       549.611  ...        61.304
# 3        350.938         331.142  1.604       623.362  ...        68.496
# 4        351.640         332.709    NaN       638.672  ...        70.022
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %% [markdown]
# Checking the missing values

# %%
df.isnull().sum()
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             5
# BF-CMratio          17
# BlowFlow            16
# ChipLevel4           1
# T-upperExt-2         2
# T-lowerExt-2         2
# UCZAA               25
# WhiteFlow-4          1
# AAWhiteSt-4        151
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        2
# Upper-HeatT-3        2
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          2
# WeakWashF            1
# SteamHeatF-3         2
# T-Top-Chips-4        1
# SulphidityL-4      151
# dtype: int64

# %% [markdown]
# Copying original dataframe into new dataframes for performing multiple operations

# %%
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()
df5 = df.copy()
df6 = df.copy()

# %% [markdown]
# Filling missing values with:
#     1. Constant Values
#     2. Forward Fill
#     3. Backward Fill
#     4. Interpolate
#     5. Mean
#     6. Median

# %%
df1.fillna(0, inplace= True)
df1
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df2.fillna(method='ffill', inplace= True)
df2
# Out:
# C:\Users\arnab\AppData\Local\Temp\ipykernel_11900\2283374875.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2.fillna(method='ffill', inplace= True)
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# ...

# %%
df3.fillna(method='bfill', inplace= True)
df3
# Out:
# C:\Users\arnab\AppData\Local\Temp\ipykernel_11900\2541763230.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3.fillna(method='bfill', inplace= True)
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# ...

# %%
df4.interpolate(inplace= True)
df4
# Out:
# C:\Users\arnab\AppData\Local\Temp\ipykernel_11900\4239704403.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df4.interpolate(inplace= True)
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# ...

# %% [markdown]
# Dropping Observation column due to its format which is not supporting for filling NaN values with "Mean & Median" function

# %%
df5 = df5.drop('Observation', axis=1)
df6 = df6.drop('Observation', axis=1)

# %%
df5.fillna(df5.mean(), inplace=True)
df5
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 0      23.10    16.520     121.717  1177.607      169.805        358.282
# 1      27.60    16.810      79.022  1328.360      341.327        351.050
# 2      23.19    16.709      79.562  1329.407      239.161        350.022
# 3      23.60    16.478      81.011  1334.877      213.527        350.938
# 4      22.90    15.618      93.244  1334.168      243.131        351.640
# ..       ...       ...         ...       ...          ...            ...
# 319    23.75    12.667      93.450  1178.252      276.955        347.286
# 320    19.80    12.558      94.352  1184.119      297.071        399.135
# 321    23.01    12.550      90.842  1188.517      289.826        373.633
# 322    24.32    13.083      88.910  1192.879      318.006        364.081
# 323    25.75    13.417      85.451  1186.342      248.312        356.289
#
#      T-lowerExt-2      UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...

# %%
df6.fillna(df6.median(), inplace=True)
df6
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 0      23.10    16.520     121.717  1177.607      169.805        358.282
# 1      27.60    16.810      79.022  1328.360      341.327        351.050
# 2      23.19    16.709      79.562  1329.407      239.161        350.022
# 3      23.60    16.478      81.011  1334.877      213.527        350.938
# 4      22.90    15.618      93.244  1334.168      243.131        351.640
# ..       ...       ...         ...       ...          ...            ...
# 319    23.75    12.667      93.450  1178.252      276.955        347.286
# 320    19.80    12.558      94.352  1184.119      297.071        399.135
# 321    23.01    12.550      90.842  1188.517      289.826        373.633
# 322    24.32    13.083      88.910  1192.879      318.006        364.081
# 323    25.75    13.417      85.451  1186.342      248.312        356.289
#
#      T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...

# %% [markdown]
# Dropping rows which consists any missing values & describing its accurate informations

# %%
df.dropna(axis=0, inplace=True)
df.isnull().sum()
# Out:
# Observation        0
# Y-Kappa            0
# ChipRate           0
# BF-CMratio         0
# BlowFlow           0
# ChipLevel4         0
# T-upperExt-2       0
# T-lowerExt-2       0
# UCZAA              0
# WhiteFlow-4        0
# AAWhiteSt-4        0
# AA-Wood-4          0
# ChipMoisture-4     0
# SteamFlow-4        0
# Lower-HeatT-3      0
# Upper-HeatT-3      0
# ChipMass-4         0
# WeakLiquorF        0
# BlackFlow-2        0
# WeakWashF          0
# SteamHeatF-3       0
# T-Top-Chips-4      0
# SulphidityL-4      0
# dtype: int64

# %%
print(df.describe())
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  141.000000  141.000000  141.000000   141.000000   141.000000
# mean    20.780567   14.407277   86.842078  1241.878766   267.190312
# std      3.104667    1.501403    7.447316    72.414829    80.965627
# min     12.170000   10.833000   68.645000   954.092000     0.000000
# 25%     18.500000   13.420000   81.087000  1194.181000   219.669000
# 50%     20.750000   14.375000   86.950000  1276.082000   276.955000
# 75%     23.300000   15.542000   92.142000  1290.006000   332.497000
# max     27.600000   16.817000  114.570000  1334.892000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     141.000000      141.000000  141.000000    141.000000    141.000000
# mean      356.841801      324.062270    1.497695    593.977879      6.144872
# std         9.924441        7.850917    0.103568     67.695750      0.080408
# ...
